# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\hp\anaconda3\lib\site-packages (8.2.98)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ultralytics) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\hp\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush", "food", "water"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 203.2ms
# Confidence ---> 0.68
# Class name --> person
# Speed: 13.6ms preprocess, 203.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 6.6ms preprocess, 189.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 160.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 179.0ms
# Confidence ---> 0.84
# Class name --> person
# Speed: 0.0ms preprocess, 179.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 175.3ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 175.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 160.2ms inference, 16.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.5ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.7ms
# Confidence ---> 0.83
# Class name --> person
# Speed: 0.0ms preprocess, 161.7ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 162.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.7ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 141.7ms inference, 15.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.0ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 183.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.9ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 1.5ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.0ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 131.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.3ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.5ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 1.1ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.6ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.5ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 121.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.7ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.2ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.8ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 1.1ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.1ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 2.8ms preprocess, 110.1ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.4ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 1.0ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.3ms
# Confidence ---> 0.89
# Class name --> person
# Speed: 0.0ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 96.9ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.2ms
# Confidence ---> 0.86
# Class name --> person
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 113.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.5ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.0ms preprocess, 111.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 96.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 96.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.1ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 0.0ms preprocess, 112.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.6ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 0.0ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.7ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.4ms
# Confidence ---> 0.85
# Class name --> person
# Speed: 2.3ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 95.5ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.0ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 100.4ms
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 3.7ms preprocess, 100.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.7ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 111.0ms
# Confidence ---> 0.5
# Class name --> person
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 0.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 94.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 0.0ms preprocess, 94.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 105.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 105.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 105.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 106.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 118.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 118.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 107.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 0.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 111.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 1.0ms preprocess, 111.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 114.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Speed: 4.5ms preprocess, 114.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 113.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 0.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 110.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 100.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.35
# Class name --> sofa
# Speed: 0.0ms preprocess, 100.7ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 couch, 96.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.26
# Class name --> sofa
# Speed: 2.1ms preprocess, 96.9ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 98.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 4.2ms preprocess, 98.7ms inference, 15.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 couch, 121.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> sofa
# Speed: 5.0ms preprocess, 121.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 142.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.5
# Class name --> tvmonitor
# Speed: 1.7ms preprocess, 142.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 108.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.5
# Class name --> chair
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.5ms preprocess, 108.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 116.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 116.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 tv, 110.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 111.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 108.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 119.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 111.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 2.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 113.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 5.1ms preprocess, 113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 1 chair, 130.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> cup
# Speed: 0.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 135.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 135.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 138.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.6
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 138.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 114.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 108.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.36
# Class name --> person
# Speed: 3.3ms preprocess, 108.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 110.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 103.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 104.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.0ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 117.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 117.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 103.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 5.0ms preprocess, 103.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 108.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 0.0ms preprocess, 108.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 135.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.4
# Class name --> pizza
# Speed: 0.0ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 dining table, 112.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.41
# Class name --> pizza
# Confidence ---> 0.37
# Class name --> diningtable
# Speed: 0.0ms preprocess, 112.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 handbag, 1 pizza, 1 couch, 1 dining table, 109.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.63
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Confidence ---> 0.3
# Class name --> sofa
# Confidence ---> 0.27
# Class name --> handbag
# Speed: 5.0ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bowl, 1 pizza, 121.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.47
# Class name --> bowl
# Confidence ---> 0.26
# Class name --> pizza
# Speed: 0.0ms preprocess, 121.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 handbag, 1 pizza, 1 chair, 1 dining table, 110.4ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> pizza
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.37
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> handbag
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 113.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.48
# Class name --> pizza
# Speed: 4.1ms preprocess, 113.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 dining table, 108.6ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.62
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> diningtable
# Speed: 0.0ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 handbag, 1 cup, 1 bowl, 1 pizza, 112.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Confidence ---> 0.4
# Class name --> bowl
# Confidence ---> 0.33
# Class name --> cup
# Confidence ---> 0.28
# Class name --> handbag
# Speed: 0.0ms preprocess, 112.4ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 dining table, 127.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.42
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> diningtable
# Speed: 3.2ms preprocess, 127.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 bowl, 1 pizza, 105.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.43
# Class name --> pizza
# Confidence ---> 0.35
# Class name --> bowl
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 0.0ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 pizza, 1 chair, 120.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.65
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.26
# Class name --> cup
# Speed: 0.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 chair, 115.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.43
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.0ms preprocess, 115.9ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 tv, 114.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 106.9ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.39
# Class name --> pizza
# Speed: 0.0ms preprocess, 106.9ms inference, 15.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 121.0ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.47
# Class name --> pizza
# Speed: 0.0ms preprocess, 121.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 handbag, 1 bowl, 1 pizza, 132.8ms
# Confidence ---> 0.95
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.37
# Class name --> pizza
# Confidence ---> 0.35
# Class name --> bowl
# Confidence ---> 0.28
# Class name --> handbag
# Speed: 3.7ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 tv, 115.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> pizza
# Speed: 0.0ms preprocess, 115.3ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 tv, 115.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.37
# Class name --> pizza
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 dining table, 108.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.38
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 0.0ms preprocess, 108.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tv, 109.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Speed: 2.8ms preprocess, 109.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 tv, 139.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.76
# Class name --> tvmonitor
# Confidence ---> 0.63
# Class name --> pizza
# Speed: 0.0ms preprocess, 139.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 potted plant, 1 dining table, 1 tv, 113.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.4
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> pottedplant
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 4.9ms preprocess, 113.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 chair, 1 potted plant, 1 dining table, 1 tv, 109.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.47
# Class name --> tvmonitor
# Confidence ---> 0.45
# Class name --> pizza
# Confidence ---> 0.39
# Class name --> diningtable
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.29
# Class name --> handbag
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 chair, 1 tv, 116.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> pizza
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.4
# Class name --> handbag
# Confidence ---> 0.35
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 1 tv, 122.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> pizza
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.44
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 122.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 tv, 111.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.68
# Class name --> pizza
# Confidence ---> 0.38
# Class name --> handbag
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 1.2ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 1 tv, 135.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.75
# Class name --> pizza
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.48
# Class name --> diningtable
# Confidence ---> 0.44
# Class name --> tvmonitor
# Confidence ---> 0.32
# Class name --> handbag
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 1 tv, 116.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> pizza
# Confidence ---> 0.37
# Class name --> handbag
# Confidence ---> 0.37
# Class name --> tvmonitor
# Confidence ---> 0.35
# Class name --> diningtable
# Speed: 2.4ms preprocess, 116.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 1 tv, 112.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.71
# Class name --> pizza
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.63
# Class name --> tvmonitor
# Confidence ---> 0.49
# Class name --> diningtable
# Confidence ---> 0.35
# Class name --> handbag
# Speed: 0.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 1 tv, 116.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.54
# Class name --> tvmonitor
# Confidence ---> 0.51
# Class name --> pizza
# Confidence ---> 0.37
# Class name --> diningtable
# Confidence ---> 0.32
# Class name --> handbag
# Speed: 0.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 1 tv, 109.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Confidence ---> 0.46
# Class name --> diningtable
# Confidence ---> 0.42
# Class name --> tvmonitor
# Speed: 0.0ms preprocess, 109.4ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 1 tv, 148.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.42
# Class name --> diningtable
# Confidence ---> 0.38
# Class name --> tvmonitor
# Confidence ---> 0.28
# Class name --> pizza
# Speed: 0.0ms preprocess, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 107.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.53
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 0.0ms preprocess, 107.4ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 potted plant, 1 dining table, 113.1ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.62
# Class name --> pizza
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.33
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 4.7ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 126.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.26
# Class name --> handbag
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 0.0ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 122.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.64
# Class name --> pizza
# Confidence ---> 0.6
# Class name --> person
# Speed: 0.0ms preprocess, 122.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 pizza, 125.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> pizza
# Speed: 5.0ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 113.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 4.7ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 111.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.46
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Speed: 5.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 118.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.57
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Confidence ---> 0.29
# Class name --> handbag
# Speed: 0.0ms preprocess, 118.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 144.3ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> pizza
# Confidence ---> 0.36
# Class name --> diningtable
# Speed: 0.0ms preprocess, 144.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 112.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.64
# Class name --> pizza
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 0.0ms preprocess, 112.5ms inference, 14.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 116.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.41
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 0.0ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 bowl, 1 pizza, 1 dining table, 120.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.3
# Class name --> bowl
# Confidence ---> 0.3
# Class name --> handbag
# Confidence ---> 0.29
# Class name --> pizza
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 4.4ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 128.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.42
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Confidence ---> 0.28
# Class name --> handbag
# Speed: 0.0ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 113.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.34
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> handbag
# Confidence ---> 0.26
# Class name --> diningtable
# Speed: 4.9ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 120.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.64
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Confidence ---> 0.27
# Class name --> handbag
# Speed: 0.0ms preprocess, 120.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 1 tv, 144.2ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.52
# Class name --> pizza
# Confidence ---> 0.35
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> handbag
# Speed: 0.0ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 116.9ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.68
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 5.6ms preprocess, 116.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 112.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.58
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 3.4ms preprocess, 112.6ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 122.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.72
# Class name --> pizza
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.33
# Class name --> diningtable
# Speed: 3.4ms preprocess, 122.6ms inference, 14.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 110.5ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.6
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 2.6ms preprocess, 110.5ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 112.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.63
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Speed: 2.7ms preprocess, 112.1ms inference, 13.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 147.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.62
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> diningtable
# Speed: 0.0ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 111.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Confidence ---> 0.33
# Class name --> diningtable
# Speed: 0.0ms preprocess, 111.5ms inference, 15.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 pizza, 1 dining table, 116.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.56
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> cup
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 0.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 pizza, 1 chair, 131.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.67
# Class name --> pizza
# Confidence ---> 0.34
# Class name --> chair
# Confidence ---> 0.32
# Class name --> cup
# Speed: 1.6ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 121.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.75
# Class name --> pizza
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.7ms preprocess, 121.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 dining table, 126.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.39
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 2.6ms preprocess, 126.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cup, 1 pizza, 1 dining table, 133.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.45
# Class name --> cup
# Confidence ---> 0.41
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> diningtable
# Speed: 3.6ms preprocess, 133.7ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cup, 1 pizza, 1 dining table, 122.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.46
# Class name --> cup
# Confidence ---> 0.34
# Class name --> diningtable
# Confidence ---> 0.31
# Class name --> pizza
# Speed: 0.0ms preprocess, 122.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bowl, 1 dining table, 123.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.36
# Class name --> bowl
# Confidence ---> 0.26
# Class name --> diningtable
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 123.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 dining table, 124.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 3.3ms preprocess, 124.7ms inference, 12.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 1 bottle, 1 pizza, 1 dining table, 121.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.56
# Class name --> pizza
# Confidence ---> 0.39
# Class name --> handbag
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.29
# Class name --> diningtable
# Speed: 0.0ms preprocess, 121.8ms inference, 13.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 dining table, 158.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.28
# Class name --> diningtable
# Speed: 1.0ms preprocess, 158.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 pizza, 159.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.5
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> person
# Speed: 5.3ms preprocess, 159.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 127.6ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.36
# Class name --> pizza
# Speed: 0.0ms preprocess, 127.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 1 pizza, 123.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.38
# Class name --> handbag
# Confidence ---> 0.31
# Class name --> pizza
# Speed: 3.1ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 chair, 112.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.33
# Class name --> handbag
# Speed: 5.5ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 pizza, 1 dining table, 124.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.42
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Speed: 0.0ms preprocess, 124.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 dining table, 126.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.34
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> diningtable
# Confidence ---> 0.27
# Class name --> handbag
# Speed: 1.9ms preprocess, 126.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 chair, 1 tv, 114.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.42
# Class name --> tvmonitor
# Confidence ---> 0.4
# Class name --> pizza
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.27
# Class name --> handbag
# Speed: 3.9ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 handbag, 1 pizza, 1 chair, 120.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.37
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> handbag
# Speed: 2.5ms preprocess, 120.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 1 chair, 1 tv, 122.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.52
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 3.3ms preprocess, 122.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 pizza, 2 chairs, 143.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.42
# Class name --> pizza
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.31
# Class name --> person
# ...
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.78
# Class name --> pizza
# Confidence ---> 0.36
# Class name --> pottedplant
# Confidence ---> 0.31
# Class name --> chair
# Speed: 2.6ms preprocess, 152.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 2 potted plants, 146.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.57
# Class name --> pizza
# Confidence ---> 0.33
# Class name --> pottedplant
# Confidence ---> 0.33
# Class name --> pottedplant
# Speed: 4.3ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 175.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.52
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> pottedplant
# Speed: 5.5ms preprocess, 175.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 150.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.59
# Class name --> pizza
# Speed: 3.8ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 149.9ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.79
# Class name --> pizza
# Speed: 3.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 167.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Speed: 3.4ms preprocess, 167.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 163.8ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.69
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 163.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 173.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.82
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 166.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Confidence ---> 0.34
# Class name --> pottedplant
# Speed: 5.4ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 164.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.58
# Class name --> pizza
# Confidence ---> 0.33
# Class name --> pottedplant
# Speed: 5.3ms preprocess, 164.5ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 178.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.8
# Class name --> pizza
# Confidence ---> 0.39
# Class name --> pottedplant
# Speed: 2.4ms preprocess, 178.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 168.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.81
# Class name --> pizza
# Speed: 3.6ms preprocess, 168.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 172.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Confidence ---> 0.4
# Class name --> pottedplant
# Speed: 3.3ms preprocess, 172.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 154.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.85
# Class name --> pizza
# Speed: 2.0ms preprocess, 154.7ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 168.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.82
# Class name --> pizza
# Speed: 3.4ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 156.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Speed: 3.8ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 150.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> pizza
# Speed: 4.1ms preprocess, 150.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 157.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.81
# Class name --> pizza
# Speed: 2.5ms preprocess, 157.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 166.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.81
# Class name --> pizza
# Speed: 0.0ms preprocess, 166.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 164.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> pizza
# Speed: 3.4ms preprocess, 164.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 163.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 3.8ms preprocess, 163.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 159.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.86
# Class name --> pizza
# Speed: 3.4ms preprocess, 159.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 150.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.85
# Class name --> pizza
# Confidence ---> 0.32
# Class name --> pottedplant
# Speed: 4.2ms preprocess, 150.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 169.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> pizza
# Speed: 0.0ms preprocess, 169.4ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 162.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 3.3ms preprocess, 162.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 158.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 1.6ms preprocess, 158.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 160.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Speed: 3.1ms preprocess, 160.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 153.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.44
# Class name --> pizza
# Speed: 4.3ms preprocess, 153.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 162.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.36
# Class name --> pizza
# Speed: 3.9ms preprocess, 162.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 147.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Speed: 0.0ms preprocess, 147.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 148.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.54
# Class name --> pizza
# Speed: 2.9ms preprocess, 148.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 1 potted plant, 154.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.59
# Class name --> pizza
# Confidence ---> 0.45
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 2.8ms preprocess, 154.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 166.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.56
# Class name --> pizza
# Speed: 3.0ms preprocess, 166.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 156.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.55
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 3.3ms preprocess, 156.9ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 157.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Speed: 2.3ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 156.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> pizza
# Speed: 4.1ms preprocess, 156.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 167.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.51
# Class name --> pizza
# Speed: 4.9ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 155.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.59
# Class name --> pizza
# Confidence ---> 0.28
# Class name --> pizza
# Speed: 4.8ms preprocess, 155.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 151.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.71
# Class name --> pizza
# Speed: 3.8ms preprocess, 151.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 149.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.47
# Class name --> pizza
# Speed: 1.2ms preprocess, 149.5ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 172.2ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.65
# Class name --> pizza
# Confidence ---> 0.32
# Class name --> pizza
# Speed: 3.4ms preprocess, 172.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 189.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.41
# Class name --> pizza
# Speed: 0.0ms preprocess, 189.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 171.7ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.63
# Class name --> pizza
# Confidence ---> 0.3
# Class name --> pizza
# Speed: 3.4ms preprocess, 171.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 1 potted plant, 157.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.7
# Class name --> pizza
# Confidence ---> 0.32
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 3.3ms preprocess, 157.5ms inference, 14.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 174.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.86
# Class name --> pizza
# Confidence ---> 0.68
# Class name --> pottedplant
# Speed: 3.1ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 181.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.59
# Class name --> pizza
# Speed: 2.9ms preprocess, 181.8ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 1 potted plant, 170.4ms
# Confidence ---> 0.94
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.51
# Class name --> pizza
# Confidence ---> 0.4
# Class name --> pottedplant
# Speed: 4.2ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 179.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.64
# Class name --> pizza
# Confidence ---> 0.35
# Class name --> pottedplant
# Speed: 4.2ms preprocess, 179.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 177.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.55
# Class name --> pizza
# Confidence ---> 0.55
# Class name --> pizza
# Speed: 1.7ms preprocess, 177.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 175.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.6
# Class name --> pizza
# Confidence ---> 0.47
# Class name --> pizza
# Speed: 0.0ms preprocess, 175.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 pizzas, 1 potted plant, 288.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.6
# Class name --> pizza
# Confidence ---> 0.47
# Class name --> pizza
# Confidence ---> 0.34
# Class name --> pottedplant
# Speed: 1.2ms preprocess, 288.0ms inference, 16.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 385.2ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.76
# Class name --> pizza
# Confidence ---> 0.26
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 385.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 257.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 16.5ms preprocess, 257.9ms inference, 14.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 206.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> pizza
# Confidence ---> 0.34
# Class name --> pottedplant
# Speed: 2.6ms preprocess, 206.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 230.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Confidence ---> 0.38
# Class name --> pottedplant
# Speed: 5.4ms preprocess, 230.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 220.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.58
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 268.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.66
# Class name --> pizza
# Confidence ---> 0.29
# Class name --> pottedplant
# Speed: 2.1ms preprocess, 268.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 245.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.68
# Class name --> pizza
# Speed: 7.8ms preprocess, 245.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 potted plant, 214.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.75
# Class name --> pizza
# Confidence ---> 0.27
# Class name --> pottedplant
# Speed: 0.0ms preprocess, 214.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 222.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> pizza
# Speed: 0.0ms preprocess, 222.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 285.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.65
# Class name --> pizza
# Speed: 0.0ms preprocess, 285.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 pizza, 1 chair, 204.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.73
# Class name --> pizza
# Confidence ---> 0.31
# Class name --> chair
# Speed: 8.3ms preprocess, 204.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 banana, 175.1ms

# %%
python3 -m venv yolo
# Out:
#   Cell In[1], line 1
#     python3 -m venv yolo
#                ^
# SyntaxError: invalid syntax
